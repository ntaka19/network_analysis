# %% [markdown]
# # TODO Network

# %%
# %matplotlib inline

import networkx as nx
import matplotlib
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties
from pylab import rcParams
from matplotlib import animation

plt.rcParams['font.family'] = 'IPAexGothic'
rcParams['figure.figsize'] = 10,10


#Graph = nx.DiGraph()
G=nx.Graph()

#G.add_node('差分進化法',subject='Silicon Neuron')
#G.add_node('二地域問題',subject='Economics')
#G.add_edges_from([('差分進化法','Algorithm'),('foo','bar')])

G.add_edge(0,3)
G.add_edge(0,1)
G.add_edge(1,2)
G.add_edge(2,0)
#G.add_edge(0,3)

G.add_edge(10,11)
G.add_edge(10,12)
G.add_edge(10,13)
G.add_edge(10,14)
G.add_edge(10,15)
G.add_edge(14,15)
G.add_edge(10,16)

G.add_edge(14,2)

#G.add_edge(20,
###network layout###
pos=nx.spring_layout(G)
nx.draw_networkx_edges(G,pos,width=1.0,alpha=0.5)


labels={0:"Ono's C-M 論文",1:"二地域問題",2:"Ono Diagram(P84)",3:"論文",10:"Silicon Neuron", 11:"差分進化法",12:"vhdl", 13:"デジタル回路",14:"ストロガッツ",15:"izikevich",16:"ネットワークカオス"}

nx.draw_networkx_labels(G,pos,labels,font_size=10,font_family='IPAexGothic')
plt.show()
